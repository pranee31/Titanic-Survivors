# %% [markdown]
# <a href="https://colab.research.google.com/github/pranee31/Titanic-Survivors/blob/main/titanic_survivor_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
titanic_dataset = pd.read_csv("/content/drive/MyDrive/dataset/tested.csv")

# %%
titanic_dataset.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
titanic_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %%
titanic_dataset.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
sns.countplot(x = titanic_dataset['Survived'])
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
sns.countplot(x ='Survived',hue ='Sex', data = titanic_dataset)
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
sns.countplot(x = 'Survived',hue = 'Pclass',data = titanic_dataset)
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
titanic_dataset['Age'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
sns.heatmap(titanic_dataset.isnull())
# Out:
# <Axes: >

# %%
titanic_dataset.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
titanic_dataset.dropna(inplace = True)

# %%
titanic_dataset.drop('Age',axis = 1,inplace = True)

# %%
sns.heatmap(titanic_dataset.isnull())
# Out:
# <Axes: >

# %%
titanic_dataset.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
titanic_dataset.head(5)
# Out:
#     Survived  Pclass     Sex  SibSp  Parch      Fare Embarked  Q  S  male
# 12         1       1  female      1      0   82.2667        S  0  1     0
# 14         1       1  female      1      0   61.1750        S  0  1     0
# 24         1       1  female      1      3  262.3750        C  0  0     0
# 26         1       1  female      0      1   61.9792        C  0  0     0
# 28         0       1    male      0      0   30.5000        S  0  1     1

# %%
sex = pd.get_dummies(titanic_dataset['Sex'],drop_first = True)

# %%
embark = pd.get_dummies(titanic_dataset['Embarked'],drop_first = True)
embark.head()
# Out:
#     Q  S
# 12  0  1
# 14  0  1
# 24  0  0
# 26  0  0
# 28  0  1

# %%
titanic = pd.concat([titanic_dataset,embark,sex],axis = 1)

# %%
titanic.head(5)
# Out:
#     Survived  Pclass     Sex  SibSp  Parch      Fare Embarked  Q  S  male  Q  \
# 12         1       1  female      1      0   82.2667        S  0  1     0  0
# 14         1       1  female      1      0   61.1750        S  0  1     0  0
# 24         1       1  female      1      3  262.3750        C  0  0     0  0
# 26         1       1  female      0      1   61.9792        C  0  0     0  0
# 28         0       1    male      0      0   30.5000        S  0  1     1  0
#
#     S  male
# 12  1     0
# 14  1     0
# 24  0     0
# 26  0     0
# 28  1     1

# %%
titanic.drop(['Sex'],axis =1,inplace = True)

# %%
titanic.head(5)
# Out:
#     Survived  Pclass  SibSp  Parch      Fare  Q  S  male  Q  S  male
# 12         1       1      1      0   82.2667  0  1     0  0  1     0
# 14         1       1      1      0   61.1750  0  1     0  0  1     0
# 24         1       1      1      3  262.3750  0  0     0  0  0     0
# 26         1       1      0      1   61.9792  0  0     0  0  0     0
# 28         0       1      0      0   30.5000  0  1     1  0  1     1

# %%
titanic.head()
# Out:
#     Survived  Pclass  SibSp  Parch      Fare  Q  S  male  Q  S  male
# 12         1       1      1      0   82.2667  0  1     0  0  1     0
# 14         1       1      1      0   61.1750  0  1     0  0  1     0
# 24         1       1      1      3  262.3750  0  0     0  0  0     0
# 26         1       1      0      1   61.9792  0  0     0  0  0     0
# 28         0       1      0      0   30.5000  0  1     1  0  1     1

# %%
x= titanic.drop('Survived',axis=1)
y = titanic['Survived']

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.3,random_state = 4)

# %%
titanic.head(10)
# Out:
#     Survived  Pclass  SibSp  Parch      Fare  Q  S  male  Q  S  male
# 12         1       1      1      0   82.2667  0  1     0  0  1     0
# 14         1       1      1      0   61.1750  0  1     0  0  1     0
# 24         1       1      1      3  262.3750  0  0     0  0  0     0
# 26         1       1      0      1   61.9792  0  0     0  0  0     0
# 28         0       1      0      0   30.5000  0  1     1  0  1     1
# 34         0       1      1      0   57.7500  0  0     1  0  0     1
# 44         1       1      1      0   52.5542  0  1     0  0  1     0
# 46         0       1      0      0   29.7000  0  0     1  0  0     1
# 48         1       1      0      0   76.2917  0  0     0  0  0     0
# 50         0       1      1      0   60.0000  0  1     1  0  1     1

# %%
reg = LogisticRegression()
reg.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
pred = reg.predict(x_test)

# %%
score = accuracy_score(y_test,pred)

# %%
print(score)
# Out:
# 1.0

# %%
from sklearn.metrics import classification_report

# %%
classification_report(y_test,pred)
# Out:
# '              precision    recall  f1-score   support\n\n           0       1.00      1.00      1.00        16\n           1       1.00      1.00      1.00        11\n\n    accuracy                           1.00        27\n   macro avg       1.00      1.00      1.00        27\nweighted avg       1.00      1.00      1.00        27\n'

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(y_test,pred)
# Out:
# array([[16,  0],
#        [ 0, 11]])

# %%
accuracy_score(y_test,pred)*100
# Out:
# 100.0
